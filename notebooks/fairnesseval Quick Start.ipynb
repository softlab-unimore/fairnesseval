# %%
# !pip install git+https://github.com/softlab-unimore/fairnesseval@main
# Out:
# rm: cannot remove 'fairnesseval': No such file or directory
# Collecting git+https://github.com/softlab-unimore/fairnesseval@main
#   Cloning https://github.com/softlab-unimore/fairnesseval (to revision main) to /tmp/pip-req-build-3ec0ma6p
#   Running command git clone --filter=blob:none --quiet https://github.com/softlab-unimore/fairnesseval /tmp/pip-req-build-3ec0ma6p
#   Resolved https://github.com/softlab-unimore/fairnesseval to commit 285058bc4a95da9ff4985757de299e5cf6f45239
#   Preparing metadata (setup.py) ... done
# Collecting fair-classification@ git+https://github.com/baraldian/fair-classification-python3@master (from fairnesseval==0.1.0)
#   Cloning https://github.com/baraldian/fair-classification-python3 (to revision master) to /tmp/pip-install-44pi3lql/fair-classification_214ae1fddd7844619acb26a5a6947782
#   Running command git clone --filter=blob:none --quiet https://github.com/baraldian/fair-classification-python3 /tmp/pip-install-44pi3lql/fair-classification_214ae1fddd7844619acb26a5a6947782
#   Resolved https://github.com/baraldian/fair-classification-python3 to commit a7c8a908d18dd86b8591db601691a4e42e75c5dc
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: aif360>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (0.6.1)
# Requirement already satisfied: fairlearn>=0.9.0.dev0 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (0.9.0.dev0)
# Requirement already satisfied: folktables>=0.0.12 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (0.0.12)
# Requirement already satisfied: matplotlib>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (3.7.1)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (1.25.2)
# Requirement already satisfied: pandas>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (2.0.3)
# Requirement already satisfied: Requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (2.31.0)
# Requirement already satisfied: scikit_learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (1.2.2)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (1.11.4)
# Requirement already satisfied: seaborn>=0.11.2 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (1.8.3)
# Requirement already satisfied: setuptools>=67.6.1 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (67.7.2)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (4.66.2)
# Requirement already satisfied: dccp in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (1.0.5)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (7.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->fairnesseval==0.1.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->fairnesseval==0.1.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->fairnesseval==0.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->fairnesseval==0.1.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->fairnesseval==0.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->fairnesseval==0.1.0) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>=1.0.2->fairnesseval==0.1.0) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>=1.0.2->fairnesseval==0.1.0) (3.4.0)
# Requirement already satisfied: cvxpy>=1.0 in /usr/local/lib/python3.10/dist-packages (from dccp->fairnesseval==0.1.0) (1.4.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (3.0.10)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.0->dccp->fairnesseval==0.1.0) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.0->dccp->fairnesseval==0.1.0) (2.0.13)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.0->dccp->fairnesseval==0.1.0) (0.7.1)
# Requirement already satisfied: scs>=3.0 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.0->dccp->fairnesseval==0.1.0) (3.2.4.post1)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.0->dccp->fairnesseval==0.1.0) (2.12.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->fairnesseval==0.1.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->fairnesseval==0.1.0) (6.3.3)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.1->fairnesseval==0.1.0) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.8.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (3.1.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.6.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.0.0)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.6.2->cvxpy>=1.0->dccp->fairnesseval==0.1.0) (0.1.7.post1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (4.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (2.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (4.19.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (2.22)
# Building wheels for collected packages: fairnesseval
#   Building wheel for fairnesseval (setup.py) ... done
#   Created wheel for fairnesseval: filename=fairnesseval-0.1.0-py3-none-any.whl size=66789 sha256=811b57db2ae00adb17a5832c3b8e90f2c30c6e1870947cb0e9b7b55501ec84d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w4iv4baw/wheels/f0/ae/a8/df048af1459ce9d3cd6f683b4db824dffeec6a5eae5f80b134
# Successfully built fairnesseval
# Installing collected packages: fairnesseval
#   Attempting uninstall: fairnesseval
#     Found existing installation: fairnesseval 0.1.0
#     Uninstalling fairnesseval-0.1.0:
#       Successfully uninstalled fairnesseval-0.1.0
# Successfully installed fairnesseval-0.1.0

# %%
# cd fairnesseval/
# !pwd
# !python setup.py egg_info
# cd /content

# %%
.pip install -e /content/drive/Shareddrives/SoftLab/Projects/Fairness/scalable-expgrad.
# Out:
# Obtaining file:///content/drive/Shareddrives/SoftLab/Projects/Fairness/scalable-expgrad
#   Preparing metadata (setup.py) ... done
# Collecting fairlearn@ git+https://github.com/MiroDudik/fairlearn.git@f11f99acd2ba724f9ef885973830d8f3390b0717#egg=fairlearn (from fairnesseval==0.1.0)
#   Cloning https://github.com/MiroDudik/fairlearn.git (to revision f11f99acd2ba724f9ef885973830d8f3390b0717) to /tmp/pip-install-kf7y9rrc/fairlearn_063db8f764da4f6e90feca22bc9b70ae
#   Running command git clone --filter=blob:none --quiet https://github.com/MiroDudik/fairlearn.git /tmp/pip-install-kf7y9rrc/fairlearn_063db8f764da4f6e90feca22bc9b70ae
#   Running command git rev-parse -q --verify 'sha^f11f99acd2ba724f9ef885973830d8f3390b0717'
#   Running command git fetch -q https://github.com/MiroDudik/fairlearn.git f11f99acd2ba724f9ef885973830d8f3390b0717
#   Running command git checkout -q f11f99acd2ba724f9ef885973830d8f3390b0717
#   Resolved https://github.com/MiroDudik/fairlearn.git to commit f11f99acd2ba724f9ef885973830d8f3390b0717
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fair-classification@ git+https://github.com/baraldian/fair-classification-python3@master (from fairnesseval==0.1.0)
#   Cloning https://github.com/baraldian/fair-classification-python3 (to revision master) to /tmp/pip-install-kf7y9rrc/fair-classification_ff48421c26fb44c290452470b4cc75c0
#   Running command git clone --filter=blob:none --quiet https://github.com/baraldian/fair-classification-python3 /tmp/pip-install-kf7y9rrc/fair-classification_ff48421c26fb44c290452470b4cc75c0
#   Resolved https://github.com/baraldian/fair-classification-python3 to commit a7c8a908d18dd86b8591db601691a4e42e75c5dc
#   Preparing metadata (setup.py) ... done
# Collecting aif360>=0.5.0 (from fairnesseval==0.1.0)
#   Downloading aif360-0.6.1-py3-none-any.whl (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.7/259.7 kB 4.9 MB/s eta 0:00:00
# Collecting folktables>=0.0.12 (from fairnesseval==0.1.0)
#   Downloading folktables-0.0.12-py3-none-any.whl (17 kB)
# Requirement already satisfied: matplotlib>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (3.7.1)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (1.25.2)
# Requirement already satisfied: pandas>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (2.0.3)
# Requirement already satisfied: Requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (2.31.0)
# Requirement already satisfied: scikit_learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (1.2.2)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (1.11.4)
# Requirement already satisfied: seaborn>=0.11.2 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (1.8.3)
# Requirement already satisfied: setuptools>=67.6.1 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (67.7.2)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (4.66.2)
# Collecting cvxpy>=1.4.2 (from fairnesseval==0.1.0)
#   Downloading cvxpy-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.6 MB/s eta 0:00:00
# Collecting dccp (from fairnesseval==0.1.0)
#   Downloading dccp-1.0.5-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from fairnesseval==0.1.0) (7.7.1)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.4.2->fairnesseval==0.1.0) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.4.2->fairnesseval==0.1.0) (2.0.13)
# Collecting clarabel>=0.5.0 (from cvxpy>=1.4.2->fairnesseval==0.1.0)
#   Downloading clarabel-0.7.1-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: scs>=3.0 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.4.2->fairnesseval==0.1.0) (3.2.4.post1)
# Collecting pybind11 (from cvxpy>=1.4.2->fairnesseval==0.1.0)
#   Downloading pybind11-2.12.0-py3-none-any.whl (234 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.0/235.0 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.1->fairnesseval==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->fairnesseval==0.1.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->fairnesseval==0.1.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->fairnesseval==0.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->fairnesseval==0.1.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->fairnesseval==0.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from Requests>=2.31.0->fairnesseval==0.1.0) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>=1.0.2->fairnesseval==0.1.0) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>=1.0.2->fairnesseval==0.1.0) (3.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->fairnesseval==0.1.0) (3.0.10)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->fairnesseval==0.1.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->fairnesseval==0.1.0) (6.3.3)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (4.9.0)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.6.2->cvxpy>=1.4.2->fairnesseval==0.1.0) (0.1.7.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.1->fairnesseval==0.1.0) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.8.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (3.1.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.6.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->fairnesseval==0.1.0) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (4.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (2.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (4.19.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fairnesseval==0.1.0) (2.22)
# Building wheels for collected packages: fair-classification, fairlearn
#   Building wheel for fair-classification (setup.py) ... done
#   Created wheel for fair-classification: filename=fair_classification-0.0.1-py3-none-any.whl size=40730 sha256=466cfce45eab094fb8959ec307b2c37c2fd6d9861767219ae5517dacc8a328d3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1jk6t0ap/wheels/2f/88/77/ce14494ec97ab23821c3661f45586fbb7cf5d91703dd6d6103
#   Building wheel for fairlearn (pyproject.toml) ... done
#   Created wheel for fairlearn: filename=fairlearn-0.9.0.dev0-py3-none-any.whl size=235730 sha256=0742439d07ca607cba7c5fe8239ad3bc36fb04bcea20ec6a72f44b546599c9a6
#   Stored in directory: /root/.cache/pip/wheels/34/2f/82/37825f0ebd1269db90994e0b3a366d0af2eded829c975bac38
# Successfully built fair-classification fairlearn
# Installing collected packages: pybind11, jedi, fair-classification, clarabel, folktables, fairlearn, aif360, cvxpy, dccp, fairnesseval
#   Attempting uninstall: cvxpy
#     Found existing installation: cvxpy 1.3.3
#     Uninstalling cvxpy-1.3.3:
#       Successfully uninstalled cvxpy-1.3.3
#   Running setup.py develop for fairnesseval
# Successfully installed aif360-0.6.1 clarabel-0.7.1 cvxpy-1.4.3 dccp-1.0.5 fair-classification-0.0.1 fairlearn-0.9.0.dev0 fairnesseval-0.1.0 folktables-0.0.12 jedi-0.19.1 pybind11-2.12.0

# %% [markdown]
# ### Dataset download
# Download the dataset following the instructions in aif360 errors.
# The following code should be changed according to your paths (python path especially).

# %%
# @title Code to download datasets in colab
import requests
import os

url_list = ["https://raw.githubusercontent.com/propublica/compas-analysis/master/compas-scores-two-years.csv",
            'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/german/german.data',
	'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/german/german.doc',
    'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',
	'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test',
	'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names',
            ]
compas = "/usr/local/lib/python3.10/dist-packages/aif360/data/raw/compas"
german = "/usr/local/lib/python3.10/dist-packages/aif360/data/raw/german"
adult =  "/usr/local/lib/python3.10/dist-packages/aif360/data/raw/adult"
save_path_list = [compas] + [german] *2 + [adult] * 3

for url, save_path in zip(url_list, save_path_list):
    os.makedirs(save_path, exist_ok=True)
    full_path = os.path.join(save_path, url.split('/')[-1])
    response = requests.get(url)
    with open(full_path, 'wb') as file:
        file.write(response.content)

import os
os.makedirs('cached_data/2018/1-Year', exist_ok=True)

# %%
print("🔁 Restarting kernel...")
# get_ipython().kernel.do_shutdown(True)
quit()
# Out:
# 🔁 Restarting kernel...

# %% [markdown]
# # faireval API
# This tool provides two interfaces for running fairness experiments on your data.
#
# **1. Python Interface**
# You can define the experiment settings in the form of a Python dictionary and use one of the following Python functions to run experiments:
#
# 1.1. `fairnesseval.run.launch_experiment_by_id` let you define and organize your experiments in a python module (default at `fairnesseval.experiment_definitions`). Then you will need to call this function by specifying only the id of the experiment you want to run. **This is the reccommended interface.**
#
# 1.2. `fairnesseval.run.launch_experiment_by_config` let you run an experiment by passing the dictionary of parameters of your experiment in input.
#
# **2. Command Line Interface**
# Alternatively, you can use the command line interface of `fairnesseval.run` to specify the experiment settings using traditional CLI parameters.

# %% [markdown]
# ## 1 Python Interface

# %% [markdown]
# To launch an experiment you can run Python script that read experiment parameters from a module (default at `fairnesseval.experiment_definitions`).
#
# Loading experiment definitions is more powerful and flexible, it allows to:
#
# *   launch multiple experiments in a row.
# *   specify multiple datasets.
# *   specify multiple models.
# *   configurations are more organized and readable.

# %% [markdown]
# Define your experiment in a file. (You can find example of experiment configuration in `fairnesseval.experiment_definitions`).
#
# Eg.: Create `exp_def.py` and define an experiment.
# ```python
# import itertools
# import json
#
# import pandas as pd
#
# RANDOM_SEEDs_RESTRICTED_V1 = [1]
#
# TRAIN_FRACTIONS_SMALLER_DATASETS_v1 = [0.063, 0.251, 1.]
# TRAIN_FRACTIONS_v1 = [0.001, 0.004, 0.016, 0.063, 0.251, 1]  # np.geomspace(0.001,1,7) np.linspace(0.001,1,7)
#
# experiment_definitions = [
#     {
#         'experiment_id': 'new_experiment',
#         'dataset_names': ('adult_sigmod',),
#         'model_names': ('LogisticRegression',),
#         'random_seeds': RANDOM_SEEDs_RESTRICTED_V1,
#         'results_path': './demo_results'
#     }
# ]
#
# ```

# %% [markdown]
# Copy the path to the experiment configuration file just defined.
#
# In my case: `/content/exp_def.py`
#
# Then run the experiment in Colab

# %%
import fairnesseval as fe
fe.run.launch_experiment_by_id('new_experiment', '/content/exp_def.py')

# %% [markdown]
# or save the following code in a .py file to run the experiments.
#
#
# ```python
# # FILE runner.py
# import fairnesseval as fe
#
# if __name__ == "__main__":
#     conf_todo = [
#         "new_experiment",
#         # ... (list of configurations to be executed)
#     ]
#     for x in conf_todo:
#         fe.run.launch_experiment_by_id(x, '/content/exp_def.py')
#
# ```
#
# Then launch the python script

# %%
# !python -m runner

# %% [markdown]
# Otherwise you can use `launch_experiment_by_config`.
# E.g.:

# %%
fe.run.launch_experiment_by_config(
    {
        'experiment_id': 'new_experiment',
        'dataset_names': ('adult_sigmod',),
        'model_names': ('LogisticRegression',),
        'random_seeds': [1],
        'results_path': './demo_results'
    }
    )

# %% [markdown]
# ## CLI interface
# The equivalent CLI call to run the experiment defined before is:

# %%
# %cd fairnesseval/src/fairnesseval
# !python -m run --dataset_name adult_sigmod --model_name LogisticRegression --experiment_id new_experiment --random_seeds 1 --results_path /content/demo_results
